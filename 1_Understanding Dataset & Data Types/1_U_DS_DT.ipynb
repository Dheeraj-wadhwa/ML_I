# %% [markdown]
# ## IMPORT LIBRARIES

# %%
import pandas as pd 
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#       2 import numpy as np
#
# ModuleNotFoundError: No module named 'pandas'

# %% [markdown]
# ## LOAD DATASET

# %%
titanic = pd.read_csv("titanic.csv")
student = pd.read_csv("exam_performance.csv")

# %% [markdown]
# ## DISPLAY FIRST & LAST FEW RECORDS

# %%
titanic.head(5)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
student.head(5)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0    male        group A                 high school      standard
# 1  female        group D            some high school  free/reduced
# 2    male        group E                some college  free/reduced
# 3    male        group B                 high school      standard
# 4    male        group E          associate's degree      standard
#
#   test preparation course  math score  reading score  writing score
# 0               completed          67             67             63
# 1                    none          40             59             55
# 2                    none          59             60             50
# 3                    none          77             78             68
# 4               completed          78             73             68

# %%
titanic.tail(5)
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
student.tail(5)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995    male        group C                 high school      standard
# 996    male        group D          associate's degree  free/reduced
# 997  female        group C            some high school  free/reduced
# 998  female        group C                some college      standard
# 999    male        group A                some college      standard
#
#     test preparation course  math score  reading score  writing score
# 995                    none          73             70             65
# 996               completed          85             91             92
# 997                    none          32             35             41
# 998                    none          73             74             82
# 999               completed          65             60             62

# %% [markdown]
# ## Dataset Shape

# %%
titanic.shape
# Out:
# (891, 15)

# %%
student.shape
# Out:
# (1000, 8)

# %% [markdown]
# ## Dataset Information

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    object
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    object
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), float64(2), int64(4), object(7)
# memory usage: 92.4+ KB

# %%
student.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %% [markdown]
# ## Statistical Summary

# %%
titanic.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
student.describe()
# Out:
#         math score  reading score  writing score
# count  1000.000000    1000.000000    1000.000000
# mean     66.396000      69.002000      67.738000
# std      15.402871      14.737272      15.600985
# min      13.000000      27.000000      23.000000
# 25%      56.000000      60.000000      58.000000
# 50%      66.500000      70.000000      68.000000
# 75%      77.000000      79.000000      79.000000
# max     100.000000     100.000000     100.000000

# %% [markdown]
# ## Identify Feature Types

# %%
numerical_titanic = titanic.select_dtypes(include=["int64", "float64"]).columns
categorical_titanic = titanic.select_dtypes(include=["object"]).columns

# %%
numerical_titanic
categorical_titanic
# Out:
# Index(['sex', 'embarked', 'class', 'who', 'deck', 'embark_town', 'alive'], dtype='object')

# %%
numerical_student = student.select_dtypes(include=["int64"]).columns
categorical_student = student.select_dtypes(include=["object"]).columns

# %%
numerical_student
categorical_student
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course'],
#       dtype='object')

# %% [markdown]
# ## Check Unique Values

# %%
for col in categorical_titanic:
    print(f"\n{col} unique values:")
    titanic[col].unique()
# Out:
# sex unique values:
#
# embarked unique values:
#
# class unique values:
#
# who unique values:
#
# deck unique values:
#
# embark_town unique values:
#
# alive unique values:

# %%
for col in categorical_student:
    print(f"\n{col} unique values:")
    student[col].unique()
# Out:
# gender unique values:
#
# race/ethnicity unique values:
#
# parental level of education unique values:
#
# lunch unique values:
#
# test preparation course unique values:

# %% [markdown]
# ## Identify Target Variable

# %%
target_titanic = "Survived"
target_titanic
# Out:
# 'Survived'

# %%
target_student = "math score"
target_student
# Out:
# 'math score'

# %% [markdown]
# ## Missing Value Analysis

# %%
titanic.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
student.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %% [markdown]
# ## Data Imbalance Check (Titanic Target)

# %%
titanic["survived"].value_counts()
# Out:
# survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
titanic["survived"].value_counts(normalize=True) * 100
# Out:
# survived
# 0    61.616162
# 1    38.383838
# Name: proportion, dtype: float64

# %% [markdown]
# ## ML Suitability Discussion

# %%
print("Titanic dataset is suitable for classification problems.")
print("Students dataset is suitable for regression or classification problems.")
# Out:
# Titanic dataset is suitable for classification problems.
# Students dataset is suitable for regression or classification problems.
